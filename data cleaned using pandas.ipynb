# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df= pd.read_excel(r'C:\Users\IT SUPPORT\Desktop\Pandas Project\bankruptcy.xlsx')

# %%
df
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
print(df.isna())
# Out:
#        Attr1  Attr2  Attr3  Attr4  Attr5  Attr6  Attr7  Attr8  Attr9  Attr10  \
# 0      False  False  False  False  False  False  False  False  False   False
# 1      False  False  False  False  False  False  False  False  False   False
# 2      False  False  False  False  False  False  False  False  False   False
# 3      False  False  False  False  False  False  False  False  False   False
# 4      False  False  False  False  False  False  False  False  False   False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 43400  False  False  False  False  False  False  False  False  False   False
# 43401  False  False  False  False  False  False  False  False  False   False
# 43402  False  False  False  False  False  False  False  False  False   False
# 43403  False  False  False  False  False  False  False  False  False   False
# 43404  False  False  False  False  False  False  False  False  False   False
#
# ...

# %%
print(df.isna().sum())
# Out:
# Attr1       8
# Attr2       8
# Attr3       8
# Attr4     134
# Attr5      89
#          ...
# Attr61    102
# Attr62    127
# Attr63    134
# Attr64    812
# class       0
# Length: 65, dtype: int64

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Attr1 - 0%
# Attr2 - 0%
# Attr3 - 0%
# Attr4 - 0%
# Attr5 - 0%
# Attr6 - 0%
# Attr7 - 0%
# Attr8 - 0%
# Attr9 - 0%
# Attr10 - 0%
# Attr11 - 0%
# Attr12 - 0%
# Attr13 - 0%
# Attr14 - 0%
# Attr15 - 0%
# Attr16 - 0%
# Attr17 - 0%
# Attr18 - 0%
# Attr19 - 0%
# Attr20 - 0%
# Attr21 - 13%
# Attr22 - 0%
# Attr23 - 0%
# Attr24 - 2%
# Attr25 - 0%
# Attr26 - 0%
# Attr27 - 6%
# Attr28 - 2%
# Attr29 - 0%
# Attr30 - 0%
# Attr31 - 0%
# Attr32 - 1%
# Attr33 - 0%
# Attr34 - 0%
# Attr35 - 0%
# Attr36 - 0%
# Attr37 - 44%
# Attr38 - 0%
# Attr39 - 0%
# Attr40 - 0%
# Attr41 - 2%
# Attr42 - 0%
# Attr43 - 0%
# Attr44 - 0%
# Attr45 - 5%
# Attr46 - 0%
# Attr47 - 1%
# Attr48 - 0%
# Attr49 - 0%
# Attr50 - 0%
# Attr51 - 0%
# Attr52 - 1%
# Attr53 - 2%
# Attr54 - 2%
# Attr55 - 0%
# Attr56 - 0%
# Attr57 - 0%
# Attr58 - 0%
# Attr59 - 0%
# Attr60 - 5%
# Attr61 - 0%
# Attr62 - 0%
# Attr63 - 0%
# Attr64 - 2%
# class - 0%

# %%
df_cleaned = df.dropna()

# %%
print(df_cleaned.isna().sum())
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %%
df_cleaned
# Out:
#           Attr1    Attr2     Attr3    Attr4    Attr5     Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.351  0.388250  0.249760
# 8      0.009020  0.63202  0.053735  1.12630  -37.842  0.000000  0.014434
# 12     0.266690  0.34994  0.611470  3.02430   43.087  0.559830  0.332070
# 13     0.067731  0.19885  0.081562  2.95760   90.606  0.212650  0.078063
# 14    -0.029182  0.21131  0.452640  7.57460   57.844  0.010387 -0.034653
# ...         ...      ...       ...      ...      ...       ...       ...
# 43368  0.016964  0.75503  0.081574  1.12680 -197.070  0.002708  0.016964
# 43369  0.118540  0.51946  0.376420  1.96150  -80.058  0.000000  0.118540
# 43387  0.112350  1.73990 -0.514250  0.43445  -82.297 -0.322010  0.112350
# 43388 -0.089739  1.33000 -0.314680  0.67454 -124.530 -1.260700 -0.089739
# 43400  0.012898  0.70621  0.038857  1.17220  -18.907  0.000000  0.013981
#
#          Attr8   Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
df_cleaned
df_cleaned.to_excel('bankruptcy1.xlsx', index=False)

# %%
df = df_filled = df.fillna(0)
df_filled
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
print(df_filled.isna().sum())
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %%
for col in df_filled.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Attr1 - 0%
# Attr2 - 0%
# Attr3 - 0%
# Attr4 - 0%
# Attr5 - 0%
# Attr6 - 0%
# Attr7 - 0%
# Attr8 - 0%
# Attr9 - 0%
# Attr10 - 0%
# Attr11 - 0%
# Attr12 - 0%
# Attr13 - 0%
# Attr14 - 0%
# Attr15 - 0%
# Attr16 - 0%
# Attr17 - 0%
# Attr18 - 0%
# Attr19 - 0%
# Attr20 - 0%
# Attr21 - 0%
# Attr22 - 0%
# Attr23 - 0%
# Attr24 - 0%
# Attr25 - 0%
# Attr26 - 0%
# Attr27 - 0%
# Attr28 - 0%
# Attr29 - 0%
# Attr30 - 0%
# Attr31 - 0%
# Attr32 - 0%
# Attr33 - 0%
# Attr34 - 0%
# Attr35 - 0%
# Attr36 - 0%
# Attr37 - 0%
# Attr38 - 0%
# Attr39 - 0%
# Attr40 - 0%
# Attr41 - 0%
# Attr42 - 0%
# Attr43 - 0%
# Attr44 - 0%
# Attr45 - 0%
# Attr46 - 0%
# Attr47 - 0%
# Attr48 - 0%
# Attr49 - 0%
# Attr50 - 0%
# Attr51 - 0%
# Attr52 - 0%
# Attr53 - 0%
# Attr54 - 0%
# Attr55 - 0%
# Attr56 - 0%
# Attr57 - 0%
# Attr58 - 0%
# Attr59 - 0%
# Attr60 - 0%
# Attr61 - 0%
# Attr62 - 0%
# Attr63 - 0%
# Attr64 - 0%
# class - 0%

# %%
df_filled.drop_duplicates()
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
df_filled
df_filled.to_excel('bankruptcy_cleaned.xlsx', index=False)
