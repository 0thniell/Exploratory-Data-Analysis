# %%
# !pip install scipy
# Out:
# ...
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
# ...

# %%
from scipy.io import arff
import pandas as pd

data=arff.loadarff(r"C:\Users\IT SUPPORT\Downloads\Bankruptcy\1year.arff")
df1=pd.DataFrame(data[0])
print(df1)
# Out:
#          Attr1    Attr2    Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.200550  0.37951  0.39641  2.04720   32.3510  0.388250  0.249760
# 1     0.209120  0.49988  0.47225  1.94470   14.7860  0.000000  0.258340
# 2     0.248660  0.69592  0.26713  1.55480   -1.1523  0.000000  0.309060
# 3     0.081483  0.30734  0.45879  2.49280   51.9520  0.149880  0.092704
# 4     0.187320  0.61323  0.22960  1.40630   -7.3128  0.187320  0.187320
# ...        ...      ...      ...      ...       ...       ...       ...
# 7022  0.018371  0.47410 -0.13619  0.60839  -18.4490  0.018371  0.018371
# 7023 -0.013359  0.58354 -0.02265  0.92896  -42.2320 -0.013359 -0.015036
# 7024  0.006338  0.50276  0.43923  1.87360    9.7417  0.006338  0.012022
# 7025 -0.041643  0.84810 -0.12852  0.57485 -121.9200  0.000000 -0.036795
# 7026  0.014946  0.94648  0.03211  1.03630  -20.5810  0.000000  0.015260
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
df1.to_csv('bankruptcy1.csv', index=False)

# %%
data=arff.loadarff(r"C:\Users\IT SUPPORT\Downloads\Bankruptcy\2year.arff")
df2=pd.DataFrame(data[0])
df2.to_csv('bankruptcy2.csv', index=False)

# %%
data=arff.loadarff(r"C:\Users\IT SUPPORT\Downloads\Bankruptcy\3year.arff")
df3=pd.DataFrame(data[0])
df3.to_csv('bankruptcy3.csv', index=False)

# %%
data=arff.loadarff(r"C:\Users\IT SUPPORT\Downloads\Bankruptcy\4year.arff")
df4=pd.DataFrame(data[0])
df4.to_csv('bankruptcy4.csv', index=False)

# %%
data=arff.loadarff(r"C:\Users\IT SUPPORT\Downloads\Bankruptcy\5year.arff")
df5=pd.DataFrame(data[0])
df5.to_csv('bankruptcy5.csv', index=False)

# %%
df1 = pd.read_csv('bankruptcy1.csv')
df2 = pd.read_csv('bankruptcy2.csv')
df3 = pd.read_csv('bankruptcy3.csv')
df4 = pd.read_csv('bankruptcy4.csv')
df5 = pd.read_csv('bankruptcy5.csv')

# %%
combined_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
combined_df.to_csv('bankruptcy.csv', index=False)
# Out:
# bankruptcy.csv

# %%
df = pd.read_csv('bankruptcy.csv')
df
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
# !pip install openpyxl

# %%
df = pd.read_csv('bankruptcy.csv')
df.to_excel('bankruptcy.xlsx', index=False)
